# %%
import urllib

from lxml import html

# %%
response = urllib.request.urlopen("https://www.paradescommission.org/")

# %%
data = html.parse(response)

# %%
tables = data.xpath('//table[@class="HomePageTable"]')
tables
# Out:
# [<Element table at 0x7f3944a18d60>,
#  <Element table at 0x7f394015e4f0>,
#  <Element table at 0x7f3940159090>]

# %%
parade = tables[0].xpath("./tr")[0]
parade
# Out:
# <Element tr at 0x7f3940157180>

# %%
parade_data = parade.xpath("./td")
parade_data
# Out:
# []

# %%
parade = tables[0].xpath("./tr")[1]
parade
# Out:
# <Element tr at 0x7f39401111d0>

# %%
parade_data = parade.xpath("./td")
parade_data
# Out:
# [<Element td at 0x7f3940111770>,
#  <Element td at 0x7f39401117c0>,
#  <Element td at 0x7f3940111810>,
#  <Element td at 0x7f3940111860>,
#  <Element td at 0x7f39401118b0>]

# %%
parade_detail = {}

# %%
parade_detail["date"] = parade_data[0].xpath("./span/text()")[0]

# %%
parade_detail["title"] = parade_data[1].xpath("./a/text()")

# %%
parade_detail["url"] = urllib.parse.urljoin("https://www.paradescommission.org/", parade_data[1].xpath("./a/@href")[0])

# %%
parade_detail["town"] = parade_data[2].xpath("./span/text()")[0]

# %%
parade_detail["start_time"] = parade_data[3].xpath("./text()")[0]

# %%
parade_detail["determination"] = parade_data[4].xpath("./span/text()")[0]

# %%
parade_detail
# Out:
# {'date': '06/08/2022',
#  'title': ['**The Royal Scottish Pipe Band Ass...'],
#  'url': 'https://www.paradescommission.org/viewparade.aspx?id=79282',
#  'town': 'Newcastle',
#  'start_time': '17:00',
#  'determination': 'N/A'}

# %%
response = urllib.request.urlopen(parade_detail["url"])
data = html.parse(response)

# %%
tables = data.xpath("//table[contains(@class, 'HomePageTable')]")
tables
# Out:
# [<Element table at 0x7f3940103c20>, <Element table at 0x7f3940103450>]

# %%
parade_detail["reference"] = tables[0].xpath("./tr/td/text()")[0]

# %%
for row in tables[1].xpath("./tr"):
    title = row.xpath("./th/text()")
    if len(title) > 2:
        continue
    title = title[0]
    data = row.xpath("./td/text()")
    if data:
        data = data[0]
    if title == "Start Time of Outward Route":
        parade_detail["start_time"] = data
    elif title == "Proposed Outward Route":
        parade_detail["proposed_outward_route"] = data
    elif title == "End Time of Outward Route":
        parade_detail["end_time_of_outward_route"] = data
    elif title == "Start Time of Return Route":
        parade_detail["start_time_of_return_route"] = data
    elif title == "Proposed Return Route":
        parade_detail["proposed_return_route"] = data
    elif title == "End Time of Return Route":
        parade_detail["end_time_of_return_route"] = data
    elif title == "Number of Bands":
        parade_detail["number_of_bands"] = data
    elif title == "Bands":
        parade_detail["bands"] = data
    elif title == "Expected Number of Participants":
        parade_detail["expected_participants"] = data
    elif title == "Expected Number of Supporters":
        parade_detail["expected_supporters"] = data

# %%
parade_detail
# Out:
# {'date': '06/08/2022',
#  'title': ['**The Royal Scottish Pipe Band Ass...'],
#  'url': 'https://www.paradescommission.org/viewparade.aspx?id=79282',
#  'town': 'Newcastle',
#  'start_time': '17:00',
#  'determination': 'N/A',
#  'reference': 'PAR\\92990',
#  'proposed_outward_route': 'Donard Car park',
#  'end_time_of_outward_route': '18:00',
#  'start_time_of_return_route': ' - ',
#  'proposed_return_route': [],
#  'end_time_of_return_route': ' - ',
#  'number_of_bands': '40',
#  'bands': "Drumlough pipe Band,Closkelt Pipe Band,Altnaveigh Memorial Pipe Band,Ballyboley Pipe Band,Bessbrook Crimson Arrow Pipe Band,Broughshane & District Pipe Band,Gransha Pipe Band,Harry Ferguson Memorial Pipe Band,Joseph Forde Memorial Pipe Band,Major Sinclair Memorial Pipe Band,McDonald Memorial Pipe Band,Mountjoy Pipe Band,Sgt Walker Memorial Pipe Band,Tullylagan Pipe Band,Wicklow Pipe Band,McDonald Academy Pipe Band,Augharan Pipe Band,Clontibret pipe band,Cloughfin Pipe Band,Cullybackey Junior Pipe Band,Kildoag Pipe Band,Lisnamulligan Pipe Band,McNeillstown Pipe Band ,Raphoe Pipe Band,Tamlaght O'Crilly Pipe Band,Battlehill Pipe Band,Clogher Pipe Band,Major Sinclair Memorial Junior Pipe Band,Raffrey Pipe Band,St Mary's Derrytrasna Pipe Band,Tullylagan Junior Pipe Band,Marlacoo & District Pipe Band,Matt Boyd Memorial Pipe Band,Quinn Mermorial Pipe Band ,Thiepval Memorial Pipe Band,Upper Crossgare Pipe Band,Colmcille Pipe Band,Ravara Pipe Band,Manorcunningham Pipe Band,New Ross & District Pipe Band,Police Service of Northern Ireland Pipe Band",
#  'expected_participants': '1000',
#  'expected_supporters': '500'}

# %%
import datetime
from dataclasses import dataclass


@dataclass
class ParadeItem:
    reference: str = ""
    date: str = ""
    title: str = ""
    town: str = ""
    start_time: str = ""
    determination: str = ""
    proposed_outward_route: str = ""
    end_time_of_outward_route: str = ""
    start_time_of_return_route: str = ""
    proposed_return_route: str = ""
    end_time_of_return_route: str = ""
    number_of_bands: str = ""
    bands: str = ""
    expected_participants: str = ""
    expected_supporters: str = ""
    determination_document: str = ""
    vehicle_procession: bool = False
    subject_to_covid: bool = False
    is_under_consideration: bool = False
    is_sensitive: bool = False
    is_protest: bool = False
    url: str = ""


def get_parades():
    data = html.parse(urllib.request.urlopen("https://www.paradescommission.org/"))
    tables = data.xpath('//table[@class="HomePageTable"]')
    parades = []
    for parade in tables[0].xpath("./tr"):
        parade_data = parade.xpath("./td")
        if parade_data:
            item = ParadeItem()
            item.date = parade_data[0].xpath("./span/text()")[0]

            title = parade_data[1].xpath("./a/text()")[0]
            if "**" in title:
                item.subject_to_covid = True
                title = title.replace("**", "")

            if "##" in title:
                item.vehicle_procession = True
                title = title.replace("##", "")

            item.title = title
            item.town = parade_data[2].xpath("./span/text()")[0]
            item.start_time = parade_data[3].xpath("./text()")[0]
            determination = parade_data[4].xpath("./span/text()")
            if determination:
                item.determination = determination
            item.url = (
                "https://www.paradescommission.org/"
                + parade_data[1].xpath("./a/@href")[0]
            )
            parades.append(item)
    return parades


def get_parade_detail(parade: ParadeItem):
    data = html.parse(urllib.request.urlopen(parade.url))
    tables = data.xpath("//table[contains(@class, 'HomePageTable')]")

    parade.reference = tables[0].xpath("./tr/td/text()")[0]

    for row in tables[1].xpath("./tr"):
        title = row.xpath("./th/text()")
        if len(title) > 2:
            continue
        title = title[0]
        data = row.xpath("./td/text()")
        if data:
            data = data[0]

        if title == "Start Time of Outward Route":
            parade.start_time = data
        elif title == "Proposed Outward Route":
            parade.proposed_outward_route = data
        elif title == "End Time of Outward Route":
            parade.end_time_of_outward_route = data
        elif title == "Start Time of Return Route":
            parade.start_time_of_return_route = data
        elif title == "Proposed Return Route":
            parade.proposed_return_route = data
        elif title == "End Time of Return Route":
            parade.end_time_of_return_route = data
        elif title == "Number of Bands":
            parade.number_of_bands = data
        elif title == "Bands":
            parade.bands = data
        elif title == "Expected Number of Participants":
            parade.expected_participants = data
        elif title == "Expected Number of Supporters":
            parade.expected_supporters = data
        elif title == "Determination Document":
            try:
                parade.determination_document = row.xpath("./td/a/@href")[0]
            except Exception as e:
                logger.error("error settings determination document")
    return parade
                
parades = get_parades()
results = []
start = datetime.datetime.now()
for parade in parades:
    results.append(get_parade_detail(parade))
print(datetime.datetime.now() - start)
# Out:
# 0:01:04.625112

# %%
results
# Out:
# [ParadeItem(reference='PAR\\92990', date='06/08/2022', title='The Royal Scottish Pipe Band Ass...', town='Newcastle', start_time='17:00', determination=['N/A'], proposed_outward_route='Donard Car park', end_time_of_outward_route='18:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='40', bands="Drumlough pipe Band,Closkelt Pipe Band,Altnaveigh Memorial Pipe Band,Ballyboley Pipe Band,Bessbrook Crimson Arrow Pipe Band,Broughshane & District Pipe Band,Gransha Pipe Band,Harry Ferguson Memorial Pipe Band,Joseph Forde Memorial Pipe Band,Major Sinclair Memorial Pipe Band,McDonald Memorial Pipe Band,Mountjoy Pipe Band,Sgt Walker Memorial Pipe Band,Tullylagan Pipe Band,Wicklow Pipe Band,McDonald Academy Pipe Band,Augharan Pipe Band,Clontibret pipe band,Cloughfin Pipe Band,Cullybackey Junior Pipe Band,Kildoag Pipe Band,Lisnamulligan Pipe Band,McNeillstown Pipe Band ,Raphoe Pipe Band,Tamlaght O'Crilly Pipe Band,Battlehill Pipe Band,Clogher Pipe Band,Major Sinclair Memorial Junior Pipe Band,Raffrey Pipe Band,St Mary's Derrytrasna Pipe Band,Tullylagan Junior Pipe Band,Marlacoo & District Pipe Band,Matt Boyd Memorial Pipe Band,Quinn Mermorial Pipe Band ,Thiepval Memorial Pipe Band,Upper Crossgare Pipe Band,Colmcille Pipe Band,Ravara Pipe Band,Manorcunningham Pipe Band,New Ross & District Pipe Band,Police Service of Northern Ireland Pipe Band", expected_participants='1000', expected_supporters='500', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79282'),
#  ParadeItem(reference='PAR\\94426', date='06/08/2022', title="HAMILTON'S TRUE BLUES LOL121", town='Curran', start_time='19:45', determination=['N/A'], proposed_outward_route='TOBERHEAD ROAD AT ORANGE HALL **CURRAN BAND ONLY**', end_time_of_outward_route='20:45', start_time_of_return_route='20:45', proposed_return_route='LURGANAGOOSE ROAD AT BRIDGE', end_time_of_return_route='22:00', number_of_bands='30', bands='Curran  Flute Band,Aughrim Rose of DerryAccordion Band,Castledawson First Flute Band, Lisnamorrow Flute Band,Ballymoghan Purple Guards Flute Band,Dunamoney flute band,Gortagilly Flute Band,Cranny Pipe Band,Desertmartin Accordion Band,Sons of William Maghera,Tobermore Flute Band,Knockloughrim Accordion Band,Ballinacross Accordion Band,Bellaghy Bruces True Blues Accordion ,Edan Accordion ,Staffordstown Accordion Band,Dunloy Accordion Band,Aughagaskin Flute Band,Moneymore Flute Band,Ballynenagh Flute Band,Ballyronan Accordion Band,Bovedy Flute Band,Cookstown Sons of William,Killymuck Accordion Band,Magheraglass,Ballyneal Accordion Band,Montober,Derryloran Boyne Defenders,Moneymore Accordion Band ,Annaghmore Flute Band,Castledawson,Megargy Accordion Band,Magherafelt ,Blackhill Flute Band,Tobermore,Drumnalough Flute Band,Kingsmills Flute Band,Milltown Accordion Band,Killycoogan Independent Accordion Band', expected_participants='1300', expected_supporters='200', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80626'),
#  ParadeItem(reference='PAR\\90807', date='06/08/2022', title='Sheepbridge LOL 1350', town='Newry', start_time='15:30', determination=['N/A'], proposed_outward_route='Sheepbridge Orange Hall', end_time_of_outward_route='16:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='South Down Defenders Flute Band ', expected_participants='70', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80620'),
#  ParadeItem(reference='PAR\\92537', date='06/08/2022', title='Brookeborough Royal Black Precep...', town='Brookeborough', start_time='10:15', determination=['N/A'], proposed_outward_route='The parade will leave The Brooke Memorial Orange Hall on the Lisnaskea Road', end_time_of_outward_route='11:00', start_time_of_return_route='16:30', proposed_return_route='The Parade will leave the Elim Church and proceed up the Main Street of Brookeborough to', end_time_of_return_route='17:15', number_of_bands='1', bands='Cavanaleck Pipe Band', expected_participants='95', expected_supporters='40', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78876'),
#  ParadeItem(reference='PAR\\94082', date='06/08/2022', title='Cancer Research N.I Ballymoney C...', town='Ballymoney', start_time='20:00', determination=['N/A'], proposed_outward_route='Ballymoney Showgrounds', end_time_of_outward_route='22:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='46', bands='Grove Pipe Band,Ballinrees Pipe Band,Garvagh pipe band,Tamlaght Pipe Band,Craiganee Accordian Band,vow accordian band,Lisnagrot Accordion Band,Killycoogan Independent ,Dunaghy Accordion Band,Glenkeen Flute and Fife Band,Duneaney Accordion Band,Milltown Accordion Band,Loughans Accordion Band,Ballymaconnelly Flute Band,Dunaghy Flute band,Tullaghans Flute Band,Blackhill Accordian Band ,Dervock Young Defenders,Bushside Accordion Band,Drumaheagles Young Defenders,Dunloy Accordion Band,Ballyrashane Flute Band,Pride of the Park Armoy,Garryduff Independent Flute Band,Stranocum Flute Band   ,Benvarden Flute Band,Knockloughrim Accordion Band,Eden Accordion Band Tamlaght,Killyless Accordion Band,Caheney Flute Band,Rankin Memorial Flute Band,Lavin Flute Band,Lisnamurrican Flute Band,Ulster Protestant Boys Coleraine,The Star of Knockagn Accordian Band,Pride of Ballymacash,Clough True Blues Flute Band,Crown Defenders,The Topp Star of the North Pipe,Killycoogan Accordian Band,Silver plains flute band,Bushside Ind. Flute Band,Craigywarren UVF Flute Band,Constable Anderson Flute Band,Eden Accordion Band Ballymoney,Aughafatten Coronation Accordion Band', expected_participants='1000', expected_supporters='2000', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80300'),
#  ParadeItem(reference='PAR\\94494', date='06/08/2022', title='Ballywalter Presbyterian Church ', town='Ballywalter', start_time='14:00', determination=['N/A'], proposed_outward_route='Main street', end_time_of_outward_route='17:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='60', expected_supporters='40', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80628'),
#  ParadeItem(reference='PAR\\92830', date='06/08/2022', title='Glenloughan Flute Band', town='Kilkeel', start_time='18:30', determination=['N/A'], proposed_outward_route='Glenloughan Orange Hall', end_time_of_outward_route='20:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='50', expected_supporters='0', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79154'),
#  ParadeItem(reference='PAR\\94093', date='06/08/2022', title='Necarne RBP 1236', town='Irvinestown', start_time='10:00', determination=['N/A'], proposed_outward_route='Irvinestown Orange Hall', end_time_of_outward_route='10:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Drumharvey Pipe Band', expected_participants='50', expected_supporters='20', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80303'),
#  ParadeItem(reference='PAR\\94094', date='06/08/2022', title='Necarne RBP 1236', town='Irvinestown', start_time='17:00', determination=['N/A'], proposed_outward_route='Irvinestown Orange Hall', end_time_of_outward_route='17.30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Drumharvey Pipe Band', expected_participants='50', expected_supporters='20', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80304'),
#  ParadeItem(reference='PAR\\92087', date='06/08/2022', title='Féile an Phobail', town='Belfast', start_time='13:00', determination=['N/A'], proposed_outward_route='Falls Road at Dunville Park', end_time_of_outward_route='13:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='10', bands='Chidambaram - Samba Band,Arts Ekta,Belfast Indian Beats,Croi An Duin (Heart of Down),St Josephs Pipe Band ,SalsaNI,loc-down events,Brazilian Beat NI', expected_participants='2000', expected_supporters='1500', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78480'),
#  ParadeItem(reference='PAR\\94314', date='06/08/2022', title='  "Grip Fast The Light" RBP 154 ...', town='Newtownbutler', start_time='09:45', determination='', proposed_outward_route='Main Street', end_time_of_outward_route='10:00', start_time_of_return_route='17:00', proposed_return_route='High Street', end_time_of_return_route='17:15', number_of_bands='3', bands='Newtownbutler Flute Band,Loughkillygreen Accordian Band,Wattlebridge Accordian Band', expected_participants='80', expected_supporters='0', determination_document='https://paradescommissionni.flexigrant.com/downloadfileexternal.aspx?dsid=169678', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80506'),
#  ParadeItem(reference='PAR\\92820', date='06/08/2022', title='Clogher Protestant Boys Flute Ba...', town='Waringstown', start_time='19:00', determination=['N/A'], proposed_outward_route='CLOGHER PROTESTANT BOYS ONLY', end_time_of_outward_route='20:00', start_time_of_return_route='20:00', proposed_return_route='START AT WEAVERS LANE ENTRANCE', end_time_of_return_route='22:30', number_of_bands='61', bands='Pride of Ballymacash,Loyal Sons Benagh Flute Band , Upper Bann Fusiliers Flute Band,Skeogh Flute band,Craigavon Protestant Boys Flute Band,Pride of Knockmore Flute Band ,Corbet Accordion Band ,Kinallen Flute Band ,Kilcluney Volunteers Flute Band,Lambeg Orange And Blue Flute Band,Drumderg Loyalist Flute Band,Portadown True Blues  Flute Band,Ballynahinch Protestant Boys Flute Band ,Cookstown Sons of William Flute Band ,Portrush Sons of Ulster Flute Band,Bessbrook True Blues Flute Band,South Belfast Young Conquerors ,Portadown Defenders  Flute Band,ARMAGH TRUE BLUES FLUTE BAND,South Down Defenders Flute Band ,Blackskull Orange & Blue Flute Band,Downshire Guiding Star Flute Band,Star of Down Maghera Flute Band,South Fermanagh Loyalists Flute Band,Dunamoney Flute Band,Flutes and Drums Donaghadee,Ulster Grenadiers Flute Band,Rathcoole Protestant Boys Flute Band,Dromore Sons of Ulster Flute Band,Ballymaconnelly Sons of Conquerers Flute Band,Pride of Ballybeen Flute Band,Star of the North Dollingstown Flute Band', expected_participants='2000', expected_supporters='1500', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79123'),
#  ParadeItem(reference='PAR\\94476', date='06/08/2022', title='Church Hill District LOL No 12', town='Derrygonnelly', start_time='10:00', determination=['N/A'], proposed_outward_route='Derrygonnelly Orange Hall', end_time_of_outward_route='10:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Garrison Accordion Band', expected_participants='65', expected_supporters='25', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80736'),
#  ParadeItem(reference='PAR\\94428', date='06/08/2022', title="Enniskillen 'Chosen Few' RBP 36", town='Enniskillen', start_time='09:15', determination=['N/A'], proposed_outward_route='Gaol Square', end_time_of_outward_route='10:00', start_time_of_return_route='17:15', proposed_return_route='Head Street', end_time_of_return_route='18:00', number_of_bands='1', bands='Enniskillen Pipe Band', expected_participants='50', expected_supporters='100', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80637'),
#  ParadeItem(reference='PAR\\94576', date='06/08/2022', title='Florencecourt Star of The West R...', town='Enniskillen', start_time='16:30', determination=['N/A'], proposed_outward_route='New Street Carpark', end_time_of_outward_route='18:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Florencecourt Flute Band', expected_participants='35', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80699'),
#  ParadeItem(reference='PAR\\94753', date='06/08/2022', title='RBP 463', town='Kesh', start_time='17:00', determination=['N/A'], proposed_outward_route='Main Street', end_time_of_outward_route='18:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Ardess Accordian Band', expected_participants='35', expected_supporters='10', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80888'),
#  ParadeItem(reference='PAR\\93852', date='06/08/2022', title='lisbellaw crimson arrow rbp392', town='Lisbellaw', start_time='10:30', determination=['N/A'], proposed_outward_route='Circular Road', end_time_of_outward_route='10:45', start_time_of_return_route='16:30', proposed_return_route='Lower Main Street', end_time_of_return_route='16:45', number_of_bands='1', bands='Lisbellaw Accordion Band', expected_participants='100', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=False, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80092'),
#  ParadeItem(reference='PAR\\94134', date='06/08/2022', title='Lisnaskea RBP 183', town='Lisnaskea', start_time='10:15', determination=['N/A'], proposed_outward_route='Castlebalfour Park', end_time_of_outward_route='10:45', start_time_of_return_route='16:15', proposed_return_route='Drumhaw', end_time_of_return_route='17:00', number_of_bands='1', bands='Lisnaskea Accordion Band', expected_participants='100', expected_supporters='100', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80359'),
#  ParadeItem(reference='PAR\\94598', date='06/08/2022', title='RBP 785', town='Lackey', start_time='17:00', determination=['N/A'], proposed_outward_route='Drummonds Glebe', end_time_of_outward_route='19:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Rosslea Accordion Band', expected_participants='25', expected_supporters='10', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80744'),
#  ParadeItem(reference='PAR\\94369', date='06/08/2022', title='RBP 272 Ballinamallard', town='Ballinamallard', start_time='9:30', determination=['N/A'], proposed_outward_route='Enniskillen Road', end_time_of_outward_route='10:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Ballinamallard Accordion Band', expected_participants='60', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80541'),
#  ParadeItem(reference='PAR\\94413', date='06/08/2022', title='RBP No 1018 Maguiresbridge', town='Maguiresbridge', start_time='10:30', determination=['N/A'], proposed_outward_route='Maguiresbridge Orange Hall', end_time_of_outward_route='10:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Maguiresbridge Silver Band', expected_participants='60', expected_supporters='unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80577'),
#  ParadeItem(reference='PAR\\94414', date='06/08/2022', title='RBP No 1018 Maguiresbridge', town='Maguiresbridge', start_time='12:30', determination=['N/A'], proposed_outward_route='Hunters Sports Field', end_time_of_outward_route='12:30', start_time_of_return_route='15:00', proposed_return_route='Coolcrannell Road', end_time_of_return_route='15:15', number_of_bands='37', bands='Moyne Pipe Band,Sister Susan Graham Accordion Band,Ballymagroatry Accordion Band,Coalisland Jubilee Accordion Band,Druminane Flute Band,Lissarley Flute Band,Drum Accordion Band,Killefarue Pipe,Brookborough Flute, South Fermanagh Flute Band,Mullycavan Accordion Band,Enniskillen Fusiliers ,Stonepark Accordion Band,Mullaghboy Acordion Band,Magheravealy Flute Band,Teemore Accordion Band,Newtownbutler Border Defenders Flute Band,Lisnaskea Accordion Band,Loughkillygreen Accordion Band,Inver Flute Band,Cavanaleck Pipe Band,Wattlebridge Accordian Band,Maguiresbridge Silver Band,Enniskillen Pipe Band,Tempo Silver Band,Ballinamallard Accordion Band,Lisbellaw Accordion Band,Ardess Accordian Band,Garrison Accordion Band,Bellanaleck Pipe Band,Moybrone Pipe Band,Florencecourt Flute Band,Tubrid Pipe Band,Drumharvey Pipe Band,Kilskerry Silver Band ,Trillick Pipe Band,Trory Accordion Band,Letterbreen Silver Band', expected_participants='1800', expected_supporters='1500', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80578'),
#  ParadeItem(reference='PAR\\94510', date='06/08/2022', title='No Organisation specified', town='Parkgate', start_time='14:00', determination=['N/A'], proposed_outward_route='Stirling’s Corners', end_time_of_outward_route='17:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='10', expected_supporters='10', determination_document='', vehicle_procession=False, subject_to_covid=False, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80660'),
#  ParadeItem(reference='PAR\\94492', date='06/08/2022', title='Glenelly Sheepdog Society', town='Plumbridge', start_time='15:00', determination=['N/A'], proposed_outward_route='Ligford Road', end_time_of_outward_route='15:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='50', expected_supporters='100', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80615'),
#  ParadeItem(reference='PAR\\94394', date='06/08/2022', title='RBP No 473 Gordon and Nixon Memo...', town='Rosslea', start_time='17:30', determination='', proposed_outward_route='Skip Site', end_time_of_outward_route='18:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Inver Flute Band', expected_participants='30', expected_supporters='20', determination_document='https://paradescommissionni.flexigrant.com/downloadfileexternal.aspx?dsid=169860', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80556'),
#  ParadeItem(reference='PAR\\94064', date='06/08/2022', title='RBP No 197 Tempo Star and Garter...', town='Tempo', start_time='10:15', determination=['N/A'], proposed_outward_route='Start Parochial Hall', end_time_of_outward_route='11:00', start_time_of_return_route='16:00', proposed_return_route='start at Doon Lane Enniskillen Road', end_time_of_return_route='17:30', number_of_bands='1', bands='Tempo Silver Band', expected_participants='50', expected_supporters='20', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80292'),
#  ParadeItem(reference='PAR\\94337', date='06/08/2022', title='Trillick RBP 1238', town='Trillick', start_time='09:45', determination=['N/A'], proposed_outward_route='Main Street', end_time_of_outward_route='10:15', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Kilskeery Silver Band', expected_participants='50', expected_supporters='50', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80520'),
#  ParadeItem(reference='PAR\\94232', date='06/08/2022', title='Downe Old Car Club', town='Loughinisland', start_time='10:30', determination=['N/A'], proposed_outward_route='Brennans', end_time_of_outward_route='10:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='25', expected_supporters='0', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80428'),
#  ParadeItem(reference='PAR\\94121', date='07/08/2022', title='ABOD Claudy Club', town='Claudy', start_time='15:45', determination=['N/A'], proposed_outward_route='Kilcatten Road', end_time_of_outward_route='16:00', start_time_of_return_route='16:50', proposed_return_route='Parish Church', end_time_of_return_route='16:20', number_of_bands='1', bands='Aghanaloo Flute Band', expected_participants='60', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80320'),
#  ParadeItem(reference='PAR\\94739', date='07/08/2022', title='ABOD Ballymena & District Amalga...', town='Ballymena', start_time='17:50', determination=['N/A'], proposed_outward_route='Galgorm Road (Protestant Hall)', end_time_of_outward_route='06:30', start_time_of_return_route='19:30', proposed_return_route='Casement Street', end_time_of_return_route='20:30', number_of_bands='1', bands='TBC', expected_participants='120', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80844'),
#  ParadeItem(reference='PAR\\94338', date='07/08/2022', title='RBP 1238 Trillick Star of Bethle...', town='Trillick', start_time='10:00', determination=['N/A'], proposed_outward_route='Main Street', end_time_of_outward_route='10:15', start_time_of_return_route='11:15', proposed_return_route='Leave church', end_time_of_return_route='11:30', number_of_bands='1', bands='Kilskeery Silver Band', expected_participants='50', expected_supporters='50', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80521'),
#  ParadeItem(reference='PAR\\94389', date='07/08/2022', title=' Agivey RBP 843', town='Aghadowey', start_time='18:40', determination=['N/A'], proposed_outward_route='Ardreagh Road', end_time_of_outward_route='18:55', start_time_of_return_route='19:55', proposed_return_route='Ardreagh Road', end_time_of_return_route='20:15', number_of_bands='1', bands='Rankin Memorial Flute Band', expected_participants='70', expected_supporters='unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80550'),
#  ParadeItem(reference='PAR\\94381', date='07/08/2022', title='Ballyronan ABOD', town='Ballinderry', start_time='11:45', determination=['N/A'], proposed_outward_route='Salterstown Bridge', end_time_of_outward_route='12:30', start_time_of_return_route='13:15', proposed_return_route='Ballinderry Parish Church', end_time_of_return_route='13:45', number_of_bands='1', bands='Ballyneil Accordion Band', expected_participants='70', expected_supporters='50', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80731'),
#  ParadeItem(reference='PAR\\94293', date='07/08/2022', title='Strabane RBP184', town='Strabane', start_time='14:30', determination=['N/A'], proposed_outward_route='Derry Road', end_time_of_outward_route='14:45', start_time_of_return_route='16:10', proposed_return_route='Bowling Green', end_time_of_return_route='16:45', number_of_bands='1', bands='John Sayers Memorial Band', expected_participants='150', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80460'),
#  ParadeItem(reference='PAR\\94579', date='07/08/2022', title='Newtownstewart Young Farmers Clu...', town='Newtownstewart', start_time='14:00', determination=['N/A'], proposed_outward_route='Newtownstewart', end_time_of_outward_route='16:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='150', expected_supporters='unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80694'),
#  ParadeItem(reference='PAR\\94685', date='07/08/2022', title='Aonach Mhacha', town='Co Armagh', start_time='09:00', determination=['N/A'], proposed_outward_route='Bog Road', end_time_of_outward_route='19:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='100', expected_supporters='30', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80833'),
#  ParadeItem(reference='PAR\\94259', date='07/08/2022', title='Royal Black Institution', town='Magheralin', start_time='15:10', determination=['N/A'], proposed_outward_route='Magheralin Orange Hall', end_time_of_outward_route='15:15', start_time_of_return_route='16:40', proposed_return_route='From Magheralin COI Church', end_time_of_return_route='17:00', number_of_bands='1', bands=' Upper Bann Fusiliers Flute Band', expected_participants='75', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80455'),
#  ParadeItem(reference='PAR\\94370', date='07/08/2022', title='RBP 272 Ballinamallard', town='Ballinamallard', start_time='11:00', determination=['N/A'], proposed_outward_route='Drummurry Hall', end_time_of_outward_route='11:30', start_time_of_return_route='12:30', proposed_return_route='Main Street', end_time_of_return_route='13:00', number_of_bands='1', bands='Ballinmallard Accordian Band', expected_participants='60', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80542'),
#  ParadeItem(reference='PAR\\91920', date='07/08/2022', title='Heart of the Glens Festival', town='Cushendall', start_time='13:30', determination=['N/A'], proposed_outward_route='Chapel Road', end_time_of_outward_route='15:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='15', bands='Unknown at this stage,Glens Comhaltas Group', expected_participants='100', expected_supporters='1000', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78572'),
#  ParadeItem(reference='PAR\\94315', date='07/08/2022', title='"Grip Fast The Light" RBP 154', town='Newtownbutler', start_time='19:15', determination='', proposed_outward_route='Main Street', end_time_of_outward_route='19:30', start_time_of_return_route='20:15', proposed_return_route='High Street', end_time_of_return_route='20:30', number_of_bands='1', bands='Wattlebridge Accordian Band', expected_participants='60', expected_supporters='0', determination_document='https://paradescommissionni.flexigrant.com/downloadfileexternal.aspx?dsid=169659', vehicle_procession=False, subject_to_covid=False, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80511'),
#  ParadeItem(reference='PAR\\94221', date='07/08/2022', title='Lámh Dhearg CLG', town='Belfast', start_time='13:15', determination=['N/A'], proposed_outward_route='Hannahstown Hill', end_time_of_outward_route='15:15', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands=' - ', expected_participants='300', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80413'),
#  ParadeItem(reference='PAR\\94460', date='07/08/2022', title='RBP 405 ', town='Beragh', start_time='09:45', determination=['N/A'], proposed_outward_route='Church Road', end_time_of_outward_route='10:00', start_time_of_return_route='11:00', proposed_return_route='Clogherney Parish Church', end_time_of_return_route='11:15', number_of_bands='1', bands='Gortaclare Pipe Band', expected_participants='30', expected_supporters='5', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80644'),
#  ParadeItem(reference='PAR\\94135', date='07/08/2022', title='Ballybriest RBP 303', town='Cookstown', start_time='15:30', determination=['N/A'], proposed_outward_route='Lough Fea Road', end_time_of_outward_route='16:00', start_time_of_return_route='17:00', proposed_return_route='Claggan Road', end_time_of_return_route='17:30', number_of_bands='1', bands='Ballybriest Pipe Band', expected_participants='60', expected_supporters='N/A', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80361'),
#  ParadeItem(reference='PAR\\94622', date='07/08/2022', title='ABOD Mitchelburne Club Killowen ...', town='Coleraine', start_time='17:30', determination=['N/A'], proposed_outward_route='Shuttle Hill', end_time_of_outward_route='18:00', start_time_of_return_route='19:10', proposed_return_route='Killowen Street', end_time_of_return_route='20:00', number_of_bands='1', bands='Ulster Protestant Boys', expected_participants='100', expected_supporters='n/a', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80756'),
#  ParadeItem(reference='PAR\\94340', date='07/08/2022', title='WALKER CLUB ABOD', town='Armagh', start_time='15:00', determination=['N/A'], proposed_outward_route='MALL EAST', end_time_of_outward_route='15:30', start_time_of_return_route='16:30', proposed_return_route='ABBEY STREET', end_time_of_return_route='17:30', number_of_bands='1', bands='Clarke Memorial Flute Band', expected_participants='100', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80522'),
#  ParadeItem(reference='PAR\\94245', date='07/08/2022', title='East Antrim Old Vehicle Club...', town='Co Antrim', start_time='11.30', determination=['N/A'], proposed_outward_route='Carnmoney Road North (Mossley Mill)', end_time_of_outward_route='16.30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='120', expected_supporters='0', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80437'),
#  ParadeItem(reference='PAR\\94578', date='07/08/2022', title='Woodburn Ivy Leaf RBP 17', town='Carrickfergus', start_time='15:10', determination=['N/A'], proposed_outward_route='Woodburn Orange Hall', end_time_of_outward_route='15:30', start_time_of_return_route='16:20', proposed_return_route='Carrickfergus Free Presbyterian Church', end_time_of_return_route='16:40', number_of_bands='2', bands=' Carrickfergus Defenders Flute Band,Magheramorne Silver Band', expected_participants='60', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80748'),
#  ParadeItem(reference='PAR\\92221', date='07/08/2022', title='Feile An Phobail', town='Belfast', start_time='09:00', determination=['N/A'], proposed_outward_route='Finaghy Road North', end_time_of_outward_route='11:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='1500', expected_supporters='500', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78602'),
#  ParadeItem(reference='PAR\\94499', date='07/08/2022', title='Ballymurphy Massacre Campaign Gr...', town='Belfast', start_time='12:30', determination=['N/A'], proposed_outward_route='Springfield Park', end_time_of_outward_route='14:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='500', expected_supporters='400', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80633'),
#  ParadeItem(reference='PAR\\94468', date='07/08/2022', title='No 6 Royal Black District Chapte...', town='Belfast', start_time='10:45', determination=['N/A'], proposed_outward_route='West Belfast Orange Hall', end_time_of_outward_route='11:20', start_time_of_return_route='12:40', proposed_return_route='church', end_time_of_return_route='13:15', number_of_bands='1', bands='Millar Memorial Flute Band', expected_participants='70', expected_supporters='unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80606'),
#  ParadeItem(reference='PAR\\94493', date='07/08/2022', title='ABOD No Surrender Club Lisburn', town='Lisburn', start_time='14:45', determination=['N/A'], proposed_outward_route='Wallace Avenue', end_time_of_outward_route='15:15', start_time_of_return_route='16:30', proposed_return_route='Christ Church', end_time_of_return_route='17:15', number_of_bands='4', bands='Lisburn young Defenders ,Lisburn Fuseliers Flute Band,Pride of Ballymacash Flute Band,Legananny Accordion Band', expected_participants='250', expected_supporters='unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80616'),
#  ParadeItem(reference='PAR\\94750', date='07/08/2022', title='Heber MacMahons Football Club', town='Brookeborough', start_time='11:30', determination=['N/A'], proposed_outward_route='Teigeshill Road', end_time_of_outward_route='14:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='50', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80886'),
#  ParadeItem(reference='PAR\\94616', date='07/08/2022', title='Portadown District LOL No 1', town='Portadown', start_time='***', determination='', proposed_outward_route='***', end_time_of_outward_route='**', start_time_of_return_route='13:00', proposed_return_route='Drumcree Road', end_time_of_return_route='14:30', number_of_bands='2', bands='Edgarstown Accordion Band,Star of David Accordian', expected_participants='unknown', expected_supporters='unknown', determination_document='https://paradescommissionni.flexigrant.com/downloadfileexternal.aspx?dsid=169826', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80772'),
#  ParadeItem(reference='PAR\\94626', date='07/08/2022', title='ABOD Blossomhill', town='Fintona', start_time='15:00', determination=['N/A'], proposed_outward_route='Blossom Hill Hall', end_time_of_outward_route='15:30', start_time_of_return_route='16:30', proposed_return_route='Crawfords Field', end_time_of_return_route='17:00', number_of_bands='1', bands='Blacksesiagh Accordion Band', expected_participants='50', expected_supporters='30', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80760'),
#  ParadeItem(reference='PAR\\94547', date='07/08/2022', title='Blossomhill LOL 411 (Fintona)', town='Fintona', start_time='10:00', determination=['N/A'], proposed_outward_route='Dromore Road', end_time_of_outward_route='10:00', start_time_of_return_route='11:30', proposed_return_route='Craigavon Road', end_time_of_return_route='11:30', number_of_bands='1', bands='Mullinagoagh Pipe Band,Mullinagoagh Pipe Band', expected_participants='40', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80690'),
#  ParadeItem(reference='PAR\\94385', date='07/08/2022', title='ABOD Bovevagh & Ardinariff Branc...', town='Burnfoot', start_time='9:45', determination=['N/A'], proposed_outward_route='Drumrane Road', end_time_of_outward_route='09:45', start_time_of_return_route='11:30', proposed_return_route='Camnish Road', end_time_of_return_route='12:15', number_of_bands='1', bands='Bovevagh Flute Band', expected_participants='60', expected_supporters='50', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80544'),
#  ParadeItem(reference='PAR\\94435', date='07/08/2022', title='Aontú Aontroim', town='Ballyvoy', start_time='18:00', determination=['N/A'], proposed_outward_route='Murlough Road', end_time_of_outward_route='18:15', start_time_of_return_route='19:15', proposed_return_route='Murlough Road', end_time_of_return_route='19:30', number_of_bands='1', bands='To be confirmed', expected_participants='40', expected_supporters='25', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80596'),
#  ParadeItem(reference='PAR\\94449', date='07/08/2022', title='RBP 512', town='Antrim', start_time='14:30', determination=['N/A'], proposed_outward_route='Railway Street', end_time_of_outward_route='15:00', start_time_of_return_route='16:00', proposed_return_route='All Saints Parish Church', end_time_of_return_route='16:15', number_of_bands='1', bands='Ballycraigy Sons of Ulster', expected_participants='200', expected_supporters='Unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80600'),
#  ParadeItem(reference='PAR\\94205', date='07/08/2022', title='Mullans Ind Orange Lodge', town='Rasharkin', start_time='15.00', determination=['N/A'], proposed_outward_route='Church Road (Turnpike)', end_time_of_outward_route='17:15', start_time_of_return_route='16:30', proposed_return_route='Presbyterian Church', end_time_of_return_route='17:15', number_of_bands='1', bands='Lisnagrot ', expected_participants='70', expected_supporters='None', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80394'),
#  ParadeItem(reference='PAR\\94423', date='07/08/2022', title='RBP No 63 King Hirams', town='Ballyclare', start_time='15:00', determination=['N/A'], proposed_outward_route='Beech Green', end_time_of_outward_route='15:30', start_time_of_return_route='16:40', proposed_return_route='The Entry', end_time_of_return_route='17:00', number_of_bands='1', bands='Glenwherry Ulster Convention Flute Band', expected_participants='40', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80586'),
#  ParadeItem(reference='PAR\\93538', date='08/08/2022', title='North West Mountain Rescue Team', town='Broughshane', start_time='19:00', determination=['N/A'], proposed_outward_route='Buckna Road', end_time_of_outward_route='21:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='400', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79745'),
#  ParadeItem(reference='PAR\\93855', date='08/08/2022', title='Glens CTC', town='Cushendall', start_time='18:30', determination=['N/A'], proposed_outward_route='High Street', end_time_of_outward_route='21:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='50', expected_supporters='25', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80145'),
#  ParadeItem(reference='PAR\\94276', date='10/08/2022', title='Mavemacullan Accordion Band', town='Markethill', start_time='19:30', determination=['N/A'], proposed_outward_route='Main Street', end_time_of_outward_route='22:15', start_time_of_return_route='19:45', proposed_return_route='Newry Street', end_time_of_return_route='22:30', number_of_bands='43', bands='Allistragh Flute Band,Aughnagurgan Accordion Band,Ballyrea Boyne defenders ,Ballytyrone Accordian Band,Bessbrook True Blues,Carnagh Accordion Band,Corkley Pipe Band,Downshire guiding star ,Armagh True Blues,Drum Accordion Band,Drumderg Flute Band,Rising Sons of William Cormeen ,Enagh Accordion Band,Geoghegan Memorial Pipe Band,Dunloy Accordion Band,Hamiltonsbawn Silver Band,John Hunter Memorial Accordion Band,Kilcluney Volunteers Flute Band,Markethill Protestant Boys Flute Band,Mavemacullen Accordion Band,Mullabrack Accordion Band,Portadown defenders ,Portadown true blues ,Pride of the Birches Accordion Band,Poyntzpass Silver Band,Tyrones Ditches Pipe Band,Whitewater Pipe Band,Corbet accordian,Tullyvallen Silver Band,Loyal Sons Of Benagh Flute Band,Lisbellaw Accordion Band,Drumbanagher Accordion Band,Hillhaven Flute Band,Edgarstown Accordion Band,Killeen Pipe Band,Clontibret Pipe Band,Belleek Accordion Band,Derryfubble Accordion Band,Knockloughrim Accordion Band,Donaghmore Accordion Band,Ardarragh Accordion Band,Castlederg Young Loyalist Flute Band', expected_participants='990', expected_supporters='1200', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80469'),
# ...
#  ParadeItem(reference='PAR\\93177', date='02/10/2022', title="Conor D's Memorial Tractor & T...", town='Magherafelt', start_time='13:00', determination=['N/A'], proposed_outward_route='Magherafelt', end_time_of_outward_route='13:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='o', bands=' - ', expected_participants='300', expected_supporters='300', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79438'),
#  ParadeItem(reference='PAR\\92972', date='02/10/2022', title="Conor D's Memorial Tractor & T...", town='Magherafelt', start_time='11:00', determination=['N/A'], proposed_outward_route='Magherafelt', end_time_of_outward_route='13:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='300', expected_supporters='300', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79240'),
#  ParadeItem(reference='PAR\\94477', date='08/10/2022', title='Downe Old Car Club', town='Loughinisland', start_time='10:30', determination=['N/A'], proposed_outward_route='Brennans at Loughinisland', end_time_of_outward_route='10:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='30', expected_supporters='0', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80639'),
#  ParadeItem(reference='PAR\\93751', date='09/10/2022', title="2nd Benburb Boys' Brigade ", town='Benburb', start_time='15:15', determination=['N/A'], proposed_outward_route='Main Street', end_time_of_outward_route='15:30', start_time_of_return_route='16:30', proposed_return_route='Main Street', end_time_of_return_route='16:45', number_of_bands='1', bands='Killylea Silver Band', expected_participants='90', expected_supporters='100', determination_document='', vehicle_procession=False, subject_to_covid=False, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79916'),
#  ParadeItem(reference='PAR\\94410', date='16/10/2022', title='Tyrone National Graves Associati...', town='Ardboe', start_time='15:00', determination=['N/A'], proposed_outward_route='Junction of Mullanahoe Road/Kinrush Road/Drumenny Road', end_time_of_outward_route='16:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='7', bands='Tom Clarke Memorial Band,Kevin Lynch Memorial  Band,John Brady Memorial Band,Naomh Padraig Banna Fluit,TBC,TBC,TBC', expected_participants='500', expected_supporters='100', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80726'),
#  ParadeItem(reference='PAR\\94789', date='29/10/2022', title='Ballycastle and District Vinta...', town='Armoy', start_time='12:00', determination=['N/A'], proposed_outward_route='Limepark', end_time_of_outward_route='14:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='130', expected_supporters='200', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80934'),
#  ParadeItem(reference='PAR\\92767', date='11/11/2022', title='LOL No 1916 Thiepval Memorial', town='Belfast', start_time='10:30', determination=['N/A'], proposed_outward_route='Cregagh Road (Bus Terminal/Turning Circle)', end_time_of_outward_route='10:45', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Lone Piper ', expected_participants='100', expected_supporters='unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=79059'),
#  ParadeItem(reference='PAR\\94888', date='13/11/2022', title='The Royal British Legion', town='Carrickfergus', start_time='10:25', determination=['N/A'], proposed_outward_route='Harbour Car Park', end_time_of_outward_route='10:45', start_time_of_return_route='11:40', proposed_return_route='War Memorial Gardens', end_time_of_return_route='12:00', number_of_bands='2', bands='Pride of the Raven,Shankill Defenders Flute Band', expected_participants='200', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=81035'),
#  ParadeItem(reference='PAR\\94751', date='13/11/2022', title='Seagoe Church Lads', town='Portadown', start_time='09:45', determination=['N/A'], proposed_outward_route='James Street', end_time_of_outward_route='10:20', start_time_of_return_route='11:30', proposed_return_route='Seagoe Road', end_time_of_return_route='12:15', number_of_bands='1', bands='Star of David Accordion Band', expected_participants='150', expected_supporters='100', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80887'),
#  ParadeItem(reference='PAR\\94885', date='13/11/2022', title='Dromore Royal British Legion', town='Dromore', start_time='10:45', determination=['N/A'], proposed_outward_route='Bus Station (Hillsborough Road)', end_time_of_outward_route='10:45', start_time_of_return_route='12:45', proposed_return_route='Unitarians Church', end_time_of_return_route='13:15', number_of_bands='1', bands='Skeogh Flute Band  ', expected_participants='120', expected_supporters='800', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=81003'),
#  ParadeItem(reference='PAR\\91958', date='13/11/2022', title='Sydenham Blues & Royals Flute Ba...', town='East Belfast', start_time='09:50', determination=['N/A'], proposed_outward_route='Inverary Avenue', end_time_of_outward_route='11:45', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='3', bands='Sydenham Blues and Royals Flute Band,Somme Association Members,Lol 609', expected_participants='65', expected_supporters='15', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78389'),
#  ParadeItem(reference='PAR\\93876', date='19/11/2022', title='The Well', town='Kilkeel', start_time='18:00', determination=['N/A'], proposed_outward_route='Mourne Esplanade Kilkeel', end_time_of_outward_route='21:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='100', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80156'),
#  ParadeItem(reference='PAR\\92282', date='20/11/2022', title='Sean Mcalonan Memorial Truck R...', town='Ballycastle', start_time='10:00', determination=['N/A'], proposed_outward_route='Hillside Road', end_time_of_outward_route='14:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='0', bands=' - ', expected_participants='200', expected_supporters='Unknown', determination_document='', vehicle_procession=True, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78652'),
#  ParadeItem(reference='PAR\\94940', date='26/11/2022', title='Reclaim the Night', town='Belfast', start_time='17:30', determination=['N/A'], proposed_outward_route='Writers Square', end_time_of_outward_route='19:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Chidambaram - Samba Band', expected_participants='500', expected_supporters='50', determination_document='', vehicle_procession=False, subject_to_covid=False, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=81068'),
#  ParadeItem(reference='PAR\\78690', date='03/12/2022', title="Santa's Pony Parade Committee", town='Ballycastle', start_time='12:30', determination=['N/A'], proposed_outward_route='Mary Street', end_time_of_outward_route='13:00', start_time_of_return_route='13:00', proposed_return_route='Ann Street', end_time_of_return_route='13:45', number_of_bands='0', bands=' - ', expected_participants='50', expected_supporters='75', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=66010'),
#  ParadeItem(reference='PAR\\94157', date='31/12/2022', title='The MANKINI Mile', town='Banbridge', start_time='14:00', determination=['N/A'], proposed_outward_route='Newry Road/Ford Street', end_time_of_outward_route='15:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands=' - ', expected_participants='50', expected_supporters='50', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80346'),
#  ParadeItem(reference='PAR\\92353', date='08/04/2023', title="O'Donnells Gaelic Athletic Club", town='Belfast', start_time='11.00', determination=['N/A'], proposed_outward_route='Whiterock Parade', end_time_of_outward_route='11:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Eire Nua Flute Band ', expected_participants='200', expected_supporters='50', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78744'),
#  ParadeItem(reference='PAR\\92125', date='09/04/2023', title='Eire Nua Republican Flute Band', town='Belfast', start_time='11:30-12:30', determination=['N/A'], proposed_outward_route='Newbarnsley crescent', end_time_of_outward_route='13:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands='Eire Nua Flute band ', expected_participants='60', expected_supporters='Unknown', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78515'),
#  ParadeItem(reference='PAR\\92352', date='09/04/2023', title='National Graves Association Belf...', town='Belfast', start_time='13:30', determination=['N/A'], proposed_outward_route='Beechmount Avenue', end_time_of_outward_route='14:30', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='4', bands='Eire Nua Flute Band,Allsop O Neill Band', expected_participants='1500', expected_supporters='5000', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=78743'),
#  ParadeItem(reference='PAR\\94371', date='24/06/2023', title='Threshold Sports', town="Giant's Causeway", start_time='06:30', determination=['N/A'], proposed_outward_route='Larrybane Quarry', end_time_of_outward_route='22:00', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='1', bands=' - ', expected_participants='1000', expected_supporters='100', determination_document='', vehicle_procession=False, subject_to_covid=False, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80554'),
#  ParadeItem(reference='PAR\\94032', date='30/06/2023', title='Pride Of The Park Flute Band', town='Armoy', start_time='20:00', determination=['N/A'], proposed_outward_route='Deane Park', end_time_of_outward_route='22:15', start_time_of_return_route=' - ', proposed_return_route=[], end_time_of_return_route=' - ', number_of_bands='27', bands='Pride of the Park Armoy,Moyarget Silver Plains,Mosside Accordion Band,Eden Accordion Band Rasharkin,Bushside Ind. Flute Band,Bushside Accordion Band,Tullaghans Sons of Liberty Flute Band,Dunaghy Independent Flute Band,Drumaheagles Flute Band,Ballymaconnelly Sons of Conquerors Flute Band,Benvarden True Blues,Freeman Memorial Band ,Pride of the Bann Flute Band,Dervock Young Defenders Flute Band,Giants Causeway Protestant Boys Flute Band,Stranocum Flute Band   ,Ballyquin Loyal Sons of Ulster Flute Band,Ballynarrig Pride of Orange Flute Band,Vow Accordion Band,Dunloy Accordion Band,Ahoghill Loyal Sons of William Flute Band,Randalstown Sons of Ulster Flute Band,Newbuildings Pride of the Orange & Blues,Ballykeel Flute Band,Glenkeen Flute and Fife Band,Movenis Rising Sons Of William Flute Band,Moneydig Young Conquerors Flute Band', expected_participants='760', expected_supporters='0', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=80270'),
#  ParadeItem(reference='PAR\\78691', date='02/12/2023', title="Santa's Pony Parade Committee", town='Ballycastle', start_time='12:30', determination=['N/A'], proposed_outward_route='Mary Street', end_time_of_outward_route='13:00', start_time_of_return_route='13:00', proposed_return_route='Ann Street', end_time_of_return_route='13:45', number_of_bands='0', bands=' - ', expected_participants='50', expected_supporters='75', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=66011'),
#  ParadeItem(reference='PAR\\78694', date='07/12/2024', title="Santa's Pony Parade Committee", town='Ballycastle', start_time='12:30', determination=['N/A'], proposed_outward_route='Mary Street', end_time_of_outward_route='13:00', start_time_of_return_route='13:00', proposed_return_route='Ann Street', end_time_of_return_route='13:45', number_of_bands='0', bands=' - ', expected_participants='50', expected_supporters='75', determination_document='', vehicle_procession=False, subject_to_covid=True, is_under_consideration=False, is_sensitive=False, is_protest=False, url='https://www.paradescommission.org//viewparade.aspx?id=66013')]
